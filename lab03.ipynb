# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('/content/dog.jpg', cv2.IMREAD_GRAYSCALE)
plt.imshow(image)

# %%
blurred = cv2.GaussianBlur(image,(5,5),0)
log = cv2.Laplacian(blurred, cv2.CV_64F)
log_abs = cv2.convertScaleAbs(log)

# %%
gaussian1 = cv2.GaussianBlur(image,(5,5),1)
gaussian2 = cv2.GaussianBlur(image,(5,5),2)
dog = cv2.absdiff(gaussian1, gaussian2)

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,3,1), plt.title('Original Image'), plt.imshow(image, cmap='gray')
plt.subplot(1,3,2), plt.title('LoG'), plt.imshow(log_abs, cmap='gray')
plt.subplot(1,3,3), plt.title('DoG'), plt.imshow(dog, cmap = 'gray')
plt.show()

# %%
image = cv2.imread('/content/dog.jpg')

# %%
image_color = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image_color, cmap='PuBu')

# %%
blurred = cv2.GaussianBlur(image_color,(5,5),0)
log = cv2.Laplacian(blurred, cv2.CV_64F)
log_abs = cv2.convertScaleAbs(log)

# %%
plt.imshow(log_abs, cmap='Blues')

# %%
gaussian1 = cv2.GaussianBlur(image_color,(5,5),1)
gaussian2 = cv2.GaussianBlur(image_color,(5,5),2)
dog = cv2.absdiff(gaussian1, gaussian2)

# %%
plt.imshow(dog, cmap='Greens')

# %%
image = cv2.imread('/content/dog.jpg', cv2.IMREAD_GRAYSCALE)

# %%
params = cv2.SimpleBlobDetector_Params()
params.filterByArea = True
params.minArea = 50
params.maxArea = 2000
params.filterByCircularity = False
params.minThreshold = 10
params.maxThreshold = 200

detector = cv2.SimpleBlobDetector_create(params)


keypoints = detector.detect(image)


image_with_blobs = cv2.drawKeypoints(image, keypoints, None, (0, 0, 255), cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

plt.imshow(image_with_blobs[..., ::-1])
plt.title('Blobs Detected')
plt.show()

# %%
color_image = cv2.imread('/content/dog.jpg')
gray_image = cv2.cvtColor(color_image, cv2.COLOR_BGR2GRAY)


keypoints = detector.detect(gray_image)


image_with_blobs_color = cv2.drawKeypoints(color_image, keypoints, None, (0, 255, 0), cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)


plt.imshow(image_with_blobs_color[..., ::-1])
plt.title('Blobs on Color Image')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('/content/dog.jpg',cv2.IMREAD_GRAYSCALE)

# %%
harris_corners = cv2.cornerHarris(image, blockSize=2, ksize=3, k=0.04)
harris_corners = cv2.dilate(harris_corners, None)

# %%
threshold = 0.01 * harris_corners.max()
image_with_corners = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)
image_with_corners[harris_corners > threshold] = [0, 0, 255]

# %%
threshold = 0.5 * harris_corners.max()
image_with_corners = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)
image_with_corners[harris_corners > threshold] = [0, 0, 255]

plt.imshow(image_with_corners[..., ::-1])
plt.title('Harris Corner Detection')
plt.show()

# %%
threshold = 1.0 * harris_corners.max()
image_with_corners = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)
image_with_corners[harris_corners > threshold] = [0, 0, 255]

plt.imshow(image_with_corners[..., ::-1])
plt.title('Harris Corner Detection')
plt.show()

# %%
threshold = 0.00 * harris_corners.max()
image_with_corners = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)
image_with_corners[harris_corners > threshold] = [0, 0, 255]

plt.imshow(image_with_corners[..., ::-1])
plt.title('Harris Corner Detection')
plt.show()

# %%
plt.imshow(image_with_corners[..., ::-1])
plt.title('Harris Corner Detection')
plt.show()

# %%
image = cv2.imread('/content/dog.jpg',cv2.IMREAD_GRAYSCALE)

# %%
max_corners = 50
quality_level = 0.01
min_distance = 10
corners = cv2.goodFeaturesToTrack(image, maxCorners=max_corners, qualityLevel=quality_level, minDistance=min_distance)
corners = np.int0(corners)

image_with_corners = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)
for corner in corners:
    x,y = corner.ravel()
    cv2.circle(image_with_corners, (x,y), 5, (0,0,255), -1)

plt.imshow(image_with_corners[...,::-1])
plt.title(f'Shi-Thomas Corner Detection ({max_corners} corners)')
plt.show()
# Out:
# <ipython-input-35-7c8b3ad346a1>:5: DeprecationWarning: `np.int0` is a deprecated alias for `np.intp`.  (Deprecated NumPy 1.24)
#   corners = np.int0(corners)

# %%
max_corners = 90
quality_level = 0.01
min_distance = 10
corners = cv2.goodFeaturesToTrack(image, maxCorners=max_corners, qualityLevel=quality_level, minDistance=min_distance)
corners = np.int0(corners)

image_with_corners = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)
for corner in corners:
    x,y = corner.ravel()
    cv2.circle(image_with_corners, (x,y), 5, (0,0,255), -1)

plt.imshow(image_with_corners[...,::-1])
plt.title(f'Shi-Thomas Corner Detection ({max_corners} corners)')
plt.show()
# Out:
# <ipython-input-40-1c6be262fda6>:5: DeprecationWarning: `np.int0` is a deprecated alias for `np.intp`.  (Deprecated NumPy 1.24)
#   corners = np.int0(corners)

# %%
max_corners = 100
quality_level = 0.01
min_distance = 10
corners = cv2.goodFeaturesToTrack(image, maxCorners=max_corners, qualityLevel=quality_level, minDistance=min_distance)
corners = np.int0(corners)

image_with_corners = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)
for corner in corners:
    x,y = corner.ravel()
    cv2.circle(image_with_corners, (x,y), 5, (0,0,255), -1)

plt.imshow(image_with_corners[...,::-1])
plt.title(f'Shi-Thomas Corner Detection ({max_corners} corners)')
plt.show()
# Out:
# <ipython-input-41-acdd6eeb7f3f>:5: DeprecationWarning: `np.int0` is a deprecated alias for `np.intp`.  (Deprecated NumPy 1.24)
#   corners = np.int0(corners)
